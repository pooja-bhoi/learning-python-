# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/pooja1/Downloads/archive (8)/kar_elections.csv")
df.head()
# Out:
#    AC No.           AC Name Winning Party             Winning Candidate  \
# 0       1           Nippani           BJP              SHASHIKALA JOLLE
# 1       2  Chikkodi-Sadalga           INC                GANESH HUKKERI
# 2       3            Athani           INC  MAHESH IRANAGOUDA KUMATHALLI
# 3       4            Kagwad           INC               BALASAHEB PATIL
# 4       5           Kudachi           BJP                       P RAJIV
#
#   Winner Votes Runner Up Party         Runner Up Candidate Runner Up Votes  \
# 0       87,006             INC      KAKASO PANDURANG PATIL          78,500
# 1       91,467             BJP     ANNASAHEB SHANKAR JOLLE          80,898
# 2       82,094             BJP      LAXMAN SANGAPPA SAVADI          79,763
# 3       83,060             BJP  BHARAMAGOUDA ALAGOUDA KAGE          50,118
# 4       67,781             INC          AMIT SHAMA GHATAGE          52,773
#
#   Voting Turnout % Total Voters Winning Margin District Name
# ...

# %%
df.tail()
# Out:
#      AC Name  Winning Party  Winning Candidate  Winner Votes  Runner Up Party  \
# 219    False          False              False             0            False
# 220    False          False              False             0            False
# 221    False          False              False             0            False
# 222    False          False              False             0            False
# 223    False          False              False             0            False
#
#      Runner Up Candidate  Runner Up Votes  Voting Turnout %  Total Voters  \
# 219                False                0               0.0             0
# 220                False                0               0.0             0
# 221                False                0               0.0             0
# 222                False                0               0.0             0
# 223                False                0               0.0             0
#
#      Winning Margin  District Name
# ...

# %%
df.describe()
# Out:
#            AC No.
# count  224.000000
# mean   112.500000
# std     64.807407
# min      1.000000
# 25%     56.750000
# 50%    112.500000
# 75%    168.250000
# max    224.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 223
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AC Name              222 non-null    bool
#  1   Winning Party        222 non-null    bool
#  2   Winning Candidate    222 non-null    bool
#  3   Winner Votes         222 non-null    int32
#  4   Runner Up Party      222 non-null    bool
#  5   Runner Up Candidate  222 non-null    bool
#  6   Runner Up Votes      222 non-null    int32
#  7   Voting Turnout %     222 non-null    float64
#  8   Total Voters         222 non-null    int32
#  9   Winning Margin       222 non-null    int32
#  10  District Name        222 non-null    bool
# dtypes: bool(6), float64(1), int32(4)
# memory usage: 8.2 KB

# %%
df.drop('AC No.', inplace =True, axis = 1)

# %%
df
# Out:
#               AC Name Winning Party             Winning Candidate  \
# 0             Nippani           BJP              SHASHIKALA JOLLE
# 1    Chikkodi-Sadalga           INC                GANESH HUKKERI
# 2              Athani           INC  MAHESH IRANAGOUDA KUMATHALLI
# 3              Kagwad           INC               BALASAHEB PATIL
# 4             Kudachi           BJP                       P RAJIV
# ..                ...           ...                           ...
# 219      T. Narasipur           JDS                  ASHWIN KUMAR
# 220             Hanur           INC                    R NARENDRA
# 221          Kollegal        OTHERS                      N MAHESH
# 222    Chamarajanagar           INC             PUTTARANGA SHETTY
# 223         Gundlupet           BJP             C S NIRANJANKUMAR
#
#     Winner Votes Runner Up Party           Runner Up Candidate  \
# 0         87,006             INC        KAKASO PANDURANG PATIL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AC No.               224 non-null    int64
#  1   AC Name              224 non-null    object
#  2   Winning Party        224 non-null    object
#  3   Winning Candidate    224 non-null    object
#  4   Winner Votes         224 non-null    object
#  5   Runner Up Party      224 non-null    object
#  6   Runner Up Candidate  224 non-null    object
#  7   Runner Up Votes      224 non-null    object
#  8   Voting Turnout %     224 non-null    object
#  9   Total Voters         223 non-null    object
#  10  Winning Margin       224 non-null    object
#  11  District Name        224 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 21.1+ KB

# %%
df.isna().sum()
# Out:
# AC No.                 0
# AC Name                0
# Winning Party          0
# Winning Candidate      0
# Winner Votes           0
# Runner Up Party        0
# Runner Up Candidate    0
# Runner Up Votes        0
# Voting Turnout %       0
# Total Voters           0
# Winning Margin         0
# District Name          0
# dtype: int64

# %%
lst =["Winner Votes", 'Runner Up Votes', 'Voting Turnout %', 'Total Voters', 'Winning Margin']
for i in lst:
    df[i]=df[i].str.replace(",", "")
    df[i] = df[i].str.replace("%", "")
df
# Out:
#      AC No.           AC Name Winning Party             Winning Candidate  \
# 0         1           Nippani           BJP              SHASHIKALA JOLLE
# 1         2  Chikkodi-Sadalga           INC                GANESH HUKKERI
# 2         3            Athani           INC  MAHESH IRANAGOUDA KUMATHALLI
# 3         4            Kagwad           INC               BALASAHEB PATIL
# 4         5           Kudachi           BJP                       P RAJIV
# ..      ...               ...           ...                           ...
# 219     220      T. Narasipur           JDS                  ASHWIN KUMAR
# 220     221             Hanur           INC                    R NARENDRA
# 221     222          Kollegal        OTHERS                      N MAHESH
# 222     223    Chamarajanagar           INC             PUTTARANGA SHETTY
# 223     224         Gundlupet           BJP             C S NIRANJANKUMAR
#
#     Winner Votes Runner Up Party           Runner Up Candidate  \
# ...

# %%
lst1 =['Winner Votes', 'Runner Up Votes', 'Total Voters', 'Winning Margin']
for i in lst1:
    print(i+ ":" +str(df[i].str.isnumeric().sum()))
# Out:
# Winner Votes:222
# Runner Up Votes:222
# Total Voters:224
# Winning Margin:222

# %%
df[-df["Winner Votes"].str.isnumeric()]
# Out:
#                  AC Name Winning Party Winning Candidate Winner Votes  \
# 153  Rajarajeshwarinagar             -                 -            -
# 172            Jayanagar             -                 -            -
#
#     Runner Up Party Runner Up Candidate Runner Up Votes Voting Turnout %  \
# 153               -                   -               -                -
# 172               -                   -               -                -
#
#     Total Voters Winning Margin      District Name
# 153       471459              -  B.B.M.P (CENTRAL)
# 172       203184              -     B.B.M.P(SOUTH)

# %%
df = df.drop(index =[153, 172], axis = 0)
df
# Out:
#      AC No.           AC Name Winning Party             Winning Candidate  \
# 0         1           Nippani           BJP              SHASHIKALA JOLLE
# 1         2  Chikkodi-Sadalga           INC                GANESH HUKKERI
# 2         3            Athani           INC  MAHESH IRANAGOUDA KUMATHALLI
# 3         4            Kagwad           INC               BALASAHEB PATIL
# 4         5           Kudachi           BJP                       P RAJIV
# ..      ...               ...           ...                           ...
# 219     220      T. Narasipur           JDS                  ASHWIN KUMAR
# 220     221             Hanur           INC                    R NARENDRA
# 221     222          Kollegal        OTHERS                      N MAHESH
# 222     223    Chamarajanagar           INC             PUTTARANGA SHETTY
# 223     224         Gundlupet           BJP             C S NIRANJANKUMAR
#
#     Winner Votes Runner Up Party           Runner Up Candidate  \
# ...

# %%
lst1 =['Winner Votes', 'Runner Up Votes', 'Total Voters', 'Winning Margin']
for i in lst1:
    print(i+ ":" +str(df[i].str.isnumeric().sum()))
# Out:
# Winner Votes:222
# Runner Up Votes:222
# Total Voters:222
# Winning Margin:222

# %%
df['Total Voters'].isna().sum()
# Out:
# 0

# %%
df = df.dropna() #here when the Totla Voters had 1 null value, all the data was showing false
df
# Out:
#      AC No.           AC Name Winning Party             Winning Candidate  \
# 0         1           Nippani           BJP              SHASHIKALA JOLLE
# 1         2  Chikkodi-Sadalga           INC                GANESH HUKKERI
# 2         3            Athani           INC  MAHESH IRANAGOUDA KUMATHALLI
# 3         4            Kagwad           INC               BALASAHEB PATIL
# 4         5           Kudachi           BJP                       P RAJIV
# ..      ...               ...           ...                           ...
# 219     220      T. Narasipur           JDS                  ASHWIN KUMAR
# 220     221             Hanur           INC                    R NARENDRA
# 221     222          Kollegal        OTHERS                      N MAHESH
# 222     223    Chamarajanagar           INC             PUTTARANGA SHETTY
# 223     224         Gundlupet           BJP             C S NIRANJANKUMAR
#
#     Winner Votes Runner Up Party           Runner Up Candidate  \
# ...

# %%
lst1 =['Winner Votes', 'Runner Up Votes', 'Total Voters', 'Winning Margin']
for i in lst1:
    df[i]=df[i].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 223
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AC No.               222 non-null    int64
#  1   AC Name              222 non-null    object
#  2   Winning Party        222 non-null    object
#  3   Winning Candidate    222 non-null    object
#  4   Winner Votes         222 non-null    int32
#  5   Runner Up Party      222 non-null    object
#  6   Runner Up Candidate  222 non-null    object
#  7   Runner Up Votes      222 non-null    int32
#  8   Voting Turnout %     222 non-null    object
#  9   Total Voters         222 non-null    int32
#  10  Winning Margin       222 non-null    int32
#  11  District Name        222 non-null    object
# dtypes: int32(4), int64(1), object(7)
# memory usage: 19.1+ KB

# %%
df["Voting Turnout %"] = df["Voting Turnout %"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 0 to 223
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AC No.               222 non-null    int64
#  1   AC Name              222 non-null    object
#  2   Winning Party        222 non-null    object
#  3   Winning Candidate    222 non-null    object
#  4   Winner Votes         222 non-null    int32
#  5   Runner Up Party      222 non-null    object
#  6   Runner Up Candidate  222 non-null    object
#  7   Runner Up Votes      222 non-null    int32
#  8   Voting Turnout %     222 non-null    float64
#  9   Total Voters         222 non-null    int32
#  10  Winning Margin       222 non-null    int32
#  11  District Name        222 non-null    object
# dtypes: float64(1), int32(4), int64(1), object(6)
# memory usage: 19.1+ KB

# %%
df["Winning Party"].value_counts().plot(kind ="bar", color ='g')
plt.xlabel('Party')
plt.ylabel('Seats Won')
plt.title('Seats Won by Parties')
# Out:
# Text(0.5, 1.0, 'Seats Won by Parties')

# %%
sns.barplot(x = df["Winning Party"], y = df["Winner Votes"])
plt.xlabel('Winning Party')
plt.ylabel('Seats Won')
plt.title('Seats Won by Parties')
plt.title('Average Seats won by winning parties')
# Out:
# Text(0.5, 1.0, 'Average Seats won by winning parties')

# %%
sns.scatterplot(x = df["Winner Votes"], y = df["Winning Margin"], hue=df["Winning Party"])
# Out:
# <Axes: xlabel='Winner Votes', ylabel='Winning Margin'>

# %%
sns.catplot(x = df["Winning Party"], y = df["Voting Turnout %"], color = "r")

# %%
sns.barplot(x = df["Winning Party"], y = df["Voting Turnout %"])
# Out:
# <Axes: xlabel='Winning Party', ylabel='Voting Turnout %'>

# %%
sns.histplot(df["Winning Margin"], bins =25, kde=True, color='g')
# Out:
# <Axes: xlabel='Winning Margin', ylabel='Count'>

# %%
df.groupby("Runner Up Party").count()
# Out:
#                  AC No.  AC Name  Winning Party  Winning Candidate  \
# Runner Up Party
# BJP                  67       67             67                 67
# INC                 112      112            112                112
# IND                   3        3              3                  3
# INDEPENDENT           1        1              1                  1
# JDS                  36       36             36                 36
# OTHERS                1        1              1                  1
# Others                1        1              1                  1
# Swaraj India          1        1              1                  1
#
#                  Winner Votes  Runner Up Candidate  Runner Up Votes  \
# Runner Up Party
# BJP                        67                   67               67
# INC                       112                  112              112
# IND                         3                    3                3
# ...

# %%
fig, ax =plt.subplots(1,2,figsize=(15,8))
plt.subplot(121)
sns.histplot(data =df, x="Total Voters", bins =30, color='g',kde=True, hue='Winning Party')
plt.title("Winner Votes Count")
plt.subplot(122)
plt.title("Runner Up Votes")
sns.histplot(data =df, x="Total Voters", bins =30, color='g',kde=True, hue='Runner Up Party')
# Out:
# <Axes: title={'center': 'Runner Up Votes'}, xlabel='Total Voters', ylabel='Count'>

# %%
sns.histplot(data =df, x="Winning Margin", color='r',kde=True, hue='Winning Party')
# Out:
# <Axes: xlabel='Winning Margin', ylabel='Count'>
