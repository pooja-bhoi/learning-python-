# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warning
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import warning
#
# ModuleNotFoundError: No module named 'warning'

# %%
df = pd.read_csv("C:/Users/pooja1/Downloads/archive (7)/Amazon.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
df.tail()
# Out:
#             Date        Open         High         Low        Close  \
# 5837  2020-07-27  3062.00000  3098.000000  3015.77002  3055.209961
# 5838  2020-07-28  3054.27002  3077.090088  2995.76001  3000.330078
# 5839  2020-07-29  3030.98999  3039.159912  2996.77002  3033.530029
# 5840  2020-07-30  3014.00000  3092.000000  3005.00000  3051.879883
# 5841  2020-07-31  3244.00000  3246.820068  3151.00000  3164.679932
#
#         Adj Close   Volume
# 5837  3055.209961  4170500
# 5838  3000.330078  3126700
# 5839  3033.530029  2974100
# 5840  3051.879883  6128300
# 5841  3164.679932  8085500

# %%
df.shape
# Out:
# (5842, 7)

# %%
df.size
# Out:
# 40894

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    2000
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5842 non-null   object
#  1   Open       5842 non-null   float64
#  2   High       5842 non-null   float64
#  3   Low        5842 non-null   float64
#  4   Close      5842 non-null   float64
#  5   Adj Close  5842 non-null   float64
#  6   Volume     5842 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 319.6+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5842.000000  5842.000000  5842.000000  5842.000000  5842.000000
# mean    372.707174   376.921392   368.114569   372.746660   372.746660
# std     585.571802   591.766458   578.660700   585.607655   585.607655
# min       1.406250     1.447917     1.312500     1.395833     1.395833
# 25%      37.955001    38.547501    37.207500    37.927499    37.927499
# 50%      83.428749    84.945000    81.656250    83.459999    83.459999
# 75%     359.729988   363.439987   356.280006   360.047501   360.047501
# max    3251.060059  3344.290039  3151.000000  3200.000000  3200.000000
#
#              Volume
# count  5.842000e+03
# mean   7.519048e+06
# std    7.282683e+06
# min    4.872000e+05
# 25%    3.684900e+06
# 50%    5.657200e+06
# 75%    8.533400e+06
# max    1.043292e+08

# %%
df.nunique()
# Out:
# Date         5842
# Open         5154
# High         5098
# Low          5103
# Close        5232
# Adj Close    5232
# Volume       5692
# dtype: int64

# %%
df = df.drop(columns = ['Adj Close'])

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083  18853200

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Close'], color ='red')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Price in USD', fontsize = '11')
plt.title('Amazon Price')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Close'], color ='red')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Price in USD', fontsize = '11')
plt.title('Amazon Price')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Volume'], color ='pink')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Volume', fontsize = '11')
plt.title('Volume Trends', fontsize = '13')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Volume'], color ='pink')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Volume', fontsize = '11')
plt.title('Volume Trends', fontsize = '13')
plt.grid()
plt.show()

# %%
df['Market Cap'] = df['Open']*df['Volume']

fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Market Cap'], color ='orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Market Cap', fontsize = '11')
plt.title('Market Cap', fontsize = '13')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Market Cap'], color ='orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Market Cap', fontsize = '11')
plt.title('Market Cap', fontsize = '13')
plt.grid()
plt.show()

# %%
df.iloc[df['Market Cap'].argmax()]
# Out:
# Date                 2020-01-31
# Open                2051.469971
# High                2055.719971
# Low                  2002.27002
# Close               2008.719971
# Volume                 15555200
# Market Cap    31911025688.28125
# Name: 5715, dtype: object

# %%
ohlc = df[(df['Date']> '1997-05-15')]
ohlc = ohlc.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']]
ohlc['Date'] = pd.to_datetime(ohlc['Date'], format='%Y-%m-%d')

fig, ax = plt.subplots(figsize = (20,8))
ax.plot(ohlc['Date'], ohlc['Market Cap'], color ='orange')
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Market Cap', fontsize = '11')
plt.title('Market Cap (After 15 May, 1997)', fontsize = '13')
plt.grid()
plt.show()

# %%
df['vol'] = (df['Close']/df['Close'].shift(1)) -1

fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['vol'], color ='purple')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.title('Volatality', fontsize = '13')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['vol'], color ='purple')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
plt.title('Volatality', fontsize = '13')
plt.grid()
plt.show()

# %%
df['vol'].hist(bins = 100, color ='green')
# Out:
# <Axes: >

# %%
df['Cumulative Return'] = (1+ df['vol']).cumprod()

fig, ax = plt.subplots(figsize = (20,8))
ax.plot(df['Date'], df['Cumulative Return'], color ='green')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Cumulative Returns', fontsize = '11')
plt.title('Cumulative Returns', fontsize = '13')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,8))
ax.bar(df['Date'], df['Cumulative Return'], color ='green')
ax.xaxis.set_major_locator(plt.MaxNLocator(15))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Cumulative Returns', fontsize = '11')
plt.title('Cumulative Returns', fontsize = '13')
plt.grid()
plt.show()

# %%
ohlc = df[(df['Date']> '1997-05-15')]
ohlc = ohlc.loc[:, ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'Cumulative Return']]
ohlc['Date'] = pd.to_datetime(ohlc['Date'], format='%Y-%m-%d')

fig, ax = plt.subplots(figsize = (20,8))
ax.plot(ohlc['Date'], ohlc['Cumulative Return'], color ='green')
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.set_xlabel('Date', fontsize = '11')
ax.set_ylabel('Cumulative Returns', fontsize = '11')
plt.title('Cumulative Returns after May 15, 1997', fontsize = '13')
plt.grid()
plt.show()

# %%
df.iloc[df['Cumulative Return'].argmax()]
# Out:
# Date                         2020-07-10
# Open                         3191.76001
# High                             3215.0
# Low                         3135.699951
# Close                            3200.0
# Volume                          5486000
# Market Cap           17509995413.574219
# vol                            0.005458
# Cumulative_Return                   1.0
# Cumulative Return            1634.04252
# Name: 5826, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import math

# %%
df['Date'] =pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
data = df.filter(['Close'])
dataset = data.values
training_data_len = math.ceil(len(dataset)*0.8)
training_data_len
# Out:
# 4674

# %%
scaler = MinMaxScaler(feature_range =(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[1.75857959e-04],
#        [1.04212099e-04],
#        [9.76988660e-05],
#        ...,
#        [9.47955432e-01],
#        [9.53692264e-01],
#        [9.88957662e-01]])

# %%
train_data = scaled_data[0: training_data_len, :]
x_train =[]
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    if i<60:
        print(x_train)
        print(y_train)       
print()

# %%
x_train, y_train =np.array(x_train), np.array(y_train)
x_train, y_train
# Out:
# (array([[1.75857959e-04, 1.04212099e-04, 9.76988660e-05, ...,
#          2.67043555e-04, 2.44247128e-04, 2.80070095e-04],
#         [1.04212099e-04, 9.76988660e-05, 7.49024391e-05, ...,
#          2.44247128e-04, 2.80070095e-04, 2.91468271e-04],
#         [9.76988660e-05, 7.49024391e-05, 9.76988660e-06, ...,
#          2.80070095e-04, 2.91468271e-04, 2.50760435e-04],
#         ...,
#         [1.65085813e-01, 1.62565965e-01, 1.62875471e-01, ...,
#          2.10908928e-01, 2.07857594e-01, 2.09855345e-01],
#         [1.62565965e-01, 1.62875471e-01, 1.64444912e-01, ...,
#          2.07857594e-01, 2.09855345e-01, 2.08976838e-01],
#         [1.62875471e-01, 1.64444912e-01, 1.68033972e-01, ...,
#          2.09855345e-01, 2.08976838e-01, 2.11321610e-01]]),
#  array([0.00029147, 0.00025076, 0.00025076, ..., 0.20897684, 0.21132161,
#         0.20740114]))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (4614, 60, 1)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences = True, input_shape =(x_train.shape[1], 1)))
model.add(LSTM(64, return_sequences = False))
model.add(Dense(32))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
# Out:
# Epoch 1/10
# 4614/4614 [==============================] - 87s 17ms/step - loss: 5.4703e-05
# Epoch 2/10
# 4614/4614 [==============================] - 76s 16ms/step - loss: 2.0367e-05
# Epoch 3/10
# 4614/4614 [==============================] - 82s 18ms/step - loss: 1.3644e-05
# Epoch 4/10
# 4614/4614 [==============================] - 90s 19ms/step - loss: 1.4571e-05
# Epoch 5/10
# 4614/4614 [==============================] - 86s 19ms/step - loss: 8.8399e-06
# Epoch 6/10
# 4614/4614 [==============================] - 90s 19ms/step - loss: 8.5472e-06
# Epoch 7/10
# 4614/4614 [==============================] - 80s 17ms/step - loss: 9.0569e-06
# Epoch 8/10
# 4614/4614 [==============================] - 83s 18ms/step - loss: 6.5470e-06
# Epoch 9/10
# 4614/4614 [==============================] - 91s 20ms/step - loss: 8.0597e-06
# Epoch 10/10
# 4614/4614 [==============================] - 91s 20ms/step - loss: 6.0189e-06

# %%
test_data =scaled_data[training_data_len -60:, :]
x_test = []
y_test = dataset[training_data_len:,:]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60: i, 0])

# %%
x_test = np.array(x_test)

# %%
x_test =np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (1168, 60, 1)

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
# Out:
# 37/37 [==============================] - 3s 13ms/step

# %%
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 54.323270249040156

# %%
train =data[: training_data_len]
valid = data[training_data_len: ]
valid['Predictions'] = predictions

plt.figure(figsize =(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize = 13)
plt.ylabel('Close Price', fontsize = 13)
plt.plot(train['Close'], linewidth = 3.5)
plt.plot(valid[['Close', 'Predictions']], linewidth = 3.5)
plt.legend(['Train', 'Valid', 'Predictions'], loc ='upper left')
plt.show()
# Out:
# C:\Users\pooja1\AppData\Local\Temp\ipykernel_51204\2815075860.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
valid
# Out:
#                   Close  Predictions
# Date
# 2015-12-10   662.320007   677.503357
# 2015-12-11   640.150024   677.081543
# 2015-12-14   657.909973   654.531738
# 2015-12-15   658.640015   674.217712
# 2015-12-16   675.770020   670.953613
# ...                 ...          ...
# 2020-07-27  3055.209961  2618.562988
# 2020-07-28  3000.330078  2641.943115
# 2020-07-29  3033.530029  2596.159668
# 2020-07-30  3051.879883  2629.017334
# 2020-07-31  3164.679932  2634.246582
#
# [1168 rows x 2 columns]

# %%
amazon_quote = pd.read_csv("C:/Users/pooja1/Downloads/archive (7)/Amazon.csv")
new_amazon_data = amazon_quote.filter(['Close'])
last_60_days = new_amazon_data[-60:].values
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price =model.predict(X_test)
pred_price = scaler.inverse_transform(pred_price)
pred_price
# Out:
# 1/1 [==============================] - 0s 134ms/step
# array([[2711.1536]], dtype=float32)
